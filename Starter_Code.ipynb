# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.columns

application_df.drop(columns=["EIN", "NAME"], inplace=True)

application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binniNG
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T8','T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17', 'T7']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     1738
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T10        528
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
counts = application_df['CLASSIFICATION'].value_counts()

# Filter only those with counts greater than 1
filtered_counts = counts[counts > 1]

filtered_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_replace = []

classification_counts = application_df['CLASSIFICATION'].value_counts()

# Filter only those with counts less than 1882
for cls, count in counts.items():
    if count < 1917:
        classifications_to_replace.append(cls)

# Display the list of classifications to be replaced
classifications_to_replace
# Out:
# ['C2100',
#  'C7000',
#  'C1700',
#  'C4000',
#  'C5000',
#  'C1270',
#  'C2700',
#  'C2800',
#  'C7100',
#  'C1300',
#  'C1280',
#  'C1230',
#  'C1400',
#  'C7200',
#  'C2300',
#  'C1240',
#  'C8000',
#  'C7120',
#  'C1500',
#  'C1800',
#  'C6000',
#  'C1250',
#  'C8200',
#  'C1238',
#  'C1278',
#  'C1235',
#  'C1237',
#  'C7210',
#  'C2400',
#  'C1720',
#  'C4100',
#  'C1257',
#  'C1600',
#  'C1260',
#  'C2710',
#  'C0',
#  'C3200',
#  'C1234',
#  'C1246',
#  'C1267',
#  'C1256',
#  'C2190',
#  'C4200',
#  'C2600',
#  'C5200',
#  'C1370',
#  'C1248',
#  'C6100',
#  'C1820',
#  'C1900',
#  'C1236',
#  'C3700',
#  'C2570',
#  'C1580',
#  'C1245',
#  'C2500',
#  'C1570',
#  'C1283',
#  'C2380',
#  'C1732',
#  'C1728',
#  'C2170',
#  'C4120',
#  'C8210',
#  'C2561',
#  'C4500',
#  'C2150']

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
application_df['CLASSIFICATION'].value_counts()

# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df.IS_SUCCESSFUL
X = application_df.drop(columns="IS_SUCCESSFUL")

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model = tf.keras.models.Sequential()

# First hidden layer
# nn_model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=40))

nn_model.add(tf.keras.layers.Dense(units=60, activation="relu", input_dim=40))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# nn_model.add(tf.keras.layers.Dense(units=25, activation="tanh"))


# nn_model.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

# nn_model.add(tf.keras.layers.Dense(units=5, activation="tanh"))

# Output layer


# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 60)                2460
#
#  dense_30 (Dense)            (None, 30)                1830
#
#  dense_31 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 4321 (16.88 KB)
# Trainable params: 4321 (16.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Compile the model
# nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
nn_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
# Train the model
# fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

fit_model = nn_model.fit(X_train_scaled, y_train, epochs=20, validation_data=(X_test_scaled, y_test))

# fit_model = nn_model.fit(X_train_scaled, y_train, epochs=20)
# Out:
# Epoch 1/20
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5758 - accuracy: 0.7197 - val_loss: 0.5673 - val_accuracy: 0.7206
# Epoch 2/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.7282 - val_loss: 0.5634 - val_accuracy: 0.7214
# Epoch 3/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5562 - accuracy: 0.7297 - val_loss: 0.5612 - val_accuracy: 0.7185
# Epoch 4/20
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5548 - accuracy: 0.7301 - val_loss: 0.5609 - val_accuracy: 0.7174
# Epoch 5/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7304 - val_loss: 0.5615 - val_accuracy: 0.7229
# Epoch 6/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5527 - accuracy: 0.7322 - val_loss: 0.5602 - val_accuracy: 0.7216
# Epoch 7/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7320 - val_loss: 0.5604 - val_accuracy: 0.7200
# Epoch 8/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5519 - accuracy: 0.7327 - val_loss: 0.5599 - val_accuracy: 0.7227
# Epoch 9/20
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5515 - accuracy: 0.7336 - val_loss: 0.5592 - val_accuracy: 0.7206
# Epoch 10/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7328 - val_loss: 0.5599 - val_accuracy: 0.7236
# Epoch 11/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5504 - accuracy: 0.7336 - val_loss: 0.5594 - val_accuracy: 0.7233
# Epoch 12/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7334 - val_loss: 0.5597 - val_accuracy: 0.7229
# Epoch 13/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5494 - accuracy: 0.7350 - val_loss: 0.5597 - val_accuracy: 0.7226
# Epoch 14/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5495 - accuracy: 0.7350 - val_loss: 0.5613 - val_accuracy: 0.7229
# Epoch 15/20
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5490 - accuracy: 0.7338 - val_loss: 0.5614 - val_accuracy: 0.7219
# Epoch 16/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7340 - val_loss: 0.5597 - val_accuracy: 0.7223
# Epoch 17/20
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5484 - accuracy: 0.7352 - val_loss: 0.5602 - val_accuracy: 0.7233
# Epoch 18/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7338 - val_loss: 0.5580 - val_accuracy: 0.7227
# Epoch 19/20
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7347 - val_loss: 0.5583 - val_accuracy: 0.7227
# Epoch 20/20
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5471 - accuracy: 0.7340 - val_loss: 0.5601 - val_accuracy: 0.7228

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=1)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 [==============================] - 1s 2ms/step - loss: 0.5601 - accuracy: 0.7228
# Loss: 0.560100793838501, Accuracy: 0.7227988243103027

# %%
nn_model.save("nn_model.h5")

# %%
# Compile and fit your model
